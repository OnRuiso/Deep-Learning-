# %% [markdown]
# # Datos del Estudiante.
#
# 1. Nombre: Luis Felipe Narváez Gómez
# 2. Código: 2312660
# 3. Universidad Santo Tomas seccional Tunja
# 4. Facultad: Ingeniería de Sistemas
# 5. Asignatura: Electiva I - Deep Learning
# 6. Periodo: 2021-2

# %% [markdown]
# # Ejercicio
#
# ## Datos del Ejercicio
#
# Crear un cuaderno de Jupiter Notebook en Pyhton 3 utilizando la herramienta de Google Colab, donde:
#
# 1. Solicite el precio de 5 productos y para cada cada uno generele el IVA del 19%
# 2. Generar el valor base de todos los productos
# 3. Generar el valor total del IVA
# 4. Generar el valor total de la Factura (valor base + IVA).
#
# Tenga presente que este codigo no debe sobrepasar las 10 lineas de codigo.

# %% [markdown]
# ## Resolución del Ejercicio

# %% [markdown]
# ### Forma Tradicional

# %%
v1 = float(input("Ingrese el valor del PRIMER producto: "))
v2 = float(input("Ingrese el valor del SEGGUNDO producto: "))
v3 = float(input("Ingrese el valor del TERCER producto: "))
v4 = float(input("Ingrese el valor del CUARTO producto: "))
v5 = float(input("Ingrese el valor del QUINTO producto: "))
valor_total_base = v1+v2+v3+v4+v5
valor_total_iva = valor_total_base*0.19
valor_total = valor_total_base + valor_total_iva
print("El valor total BASE de los cinco productos es: "+str(valor_total_base))
print("El valor total del IVA de los cinco productos es: "+str(valor_total_iva))
print("El valor Total de la compra es: "+str(valor_total))
# Out:
# Ingrese el valor del PRIMER producto: 10.5
# Ingrese el valor del SEGGUNDO producto: 10
# Ingrese el valor del TERCER producto: 10
# Ingrese el valor del CUARTO producto: 10
# Ingrese el valor del QUINTO producto: 10
# El valor total BASE de los cinco productos es: 50.5
# El valor total del IVA de los cinco productos es:9.595
# El valor Total de la compra es: 60.095

# %% [markdown]
# ### Forma Minimalista de Python

# %%
base=0
for i in range(0, 5):
  base+=float(input("ingrese el valor del num "+str(i+1)+": "))
print("\n BASE: "+str(base)+"\n IVA: "+str(base*0.19)+"\n TOTAL: "+str(iva+base))
# Out:
# ingrese el valor del num 1: 10
# ingrese el valor del num 2: 10
# ingrese el valor del num 3: 10
# ingrese el valor del num 4: 10
# ingrese el valor del num 5: 10
#
#  BASE: 50.0
#  IVA: 9.5
#  TOTAL: 59.5

# %% [markdown]
# # Datos del Estudiante.
#
# 1. Nombre: Luis Felipe Narváez Gómez
# 2. Código: 2312660
# 3. Universidad Santo Tomas seccional Tunja
# 4. Facultad: Ingeniería de Sistemas
# 5. Asignatura: Electiva I - Deep Learning
# 6. Periodo: 2021-2

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# Ejercicio para trabajar con bases de datos (DATASETS), se trabajaran con dos bases de datos por el momento:
#
# 1. "prestamos_records.csv"

# %% [markdown]
# ## Operaciones basicas con DataSeets

# %% [markdown]
# Las bases de datos se hallan en el google drive folder correspondiente. Compete llamarlas junto con las librerias.

# %% [markdown]
# ### Instalar librerias

# %%
pip install pandas

# %% [markdown]
# No deja instalar algo nuevo debido a que mantiene la version mas reciente de las librerias que en nuestro caso vamos a trabajar.

# %% [markdown]
# ### Ver las versiones de las librerias que vamos a trabajar

# %%
import sys
import scipy
import numpy
import matplotlib
import pandas
import sklearn

print('Python: {}'.format(sys.version))                   #Ver version de Python instalado en el equipo
print('SCIPY: {}'.format(scipy.__version__))              #Ver version de Scipy instalado en el equipo
print('Numpy: {}'.format(numpy.__version__))              #ver version de Numpy instalado en el equipo
print('Matplotlib: {}'.format(matplotlib.__version__))    #Ver version de Matplotlib instalado en el equipo
print('Pandas: {}'.format(pandas.__version__))            #Ver version de Pandas instalado en el equipo
print('Sklearn: {}'.format(sklearn.__version__))          #Ver version de Sklearn instalado en el equipo
# Out:
# Python: 3.7.11 (default, Jul  3 2021, 18:01:19)
# [GCC 7.5.0]
# SCIPY: 1.4.1
# Numpy: 1.19.5
# Matplotlib: 3.2.2
# Pandas: 1.1.5
# Sklearn: 0.22.2.post1

# %% [markdown]
# ### Ver todas las versiones de librerias instaladas

# %% [markdown]
# Para ver la version de todo, TODO lo que esta instalado en el equipo (Librerias).

# %%
pip freeze
# Out:
# absl-py==0.12.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.1.0
# appdirs==1.4.4
# argcomplete==1.12.3
# argon2-cffi==20.1.0
# arviz==0.11.2
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# async-generator==1.10
# atari-py==0.2.9
# atomicwrites==1.4.0
# attrs==21.2.0
# audioread==2.1.9
# autograd==1.3
# Babel==2.9.1
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==4.0.0
# blis==0.4.1
# bokeh==2.3.3
# Bottleneck==1.3.2
# branca==0.4.2
# bs4==0.0.1
# CacheControl==0.12.6
# cached-property==1.5.2
# cachetools==4.2.2
# catalogue==1.0.0
# certifi==2021.5.30
# cffi==1.14.6
# cftime==1.5.0
# chardet==3.0.4
# charset-normalizer==2.0.4
# click==7.1.2
# cloudpickle==1.3.0
# cmake==3.12.0
# cmdstanpy==0.9.5
# colorcet==2.0.6
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.3.2
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.3
# cvxopt==1.2.6
# cvxpy==1.0.31
# cycler==0.10.0
# cymem==2.0.5
# Cython==0.29.24
# daft==0.0.4
# ...

# %% [markdown]
# ### Importar Librerias

# %% [markdown]
# Se importaran las librerias que trabajaremos para este ejercicio

# %%
import numpy as np #Importa de NUMPY, con el podremos manejar vectores y matrices
import pandas as pd #Importa PANDAS, para trabajar con bases de datos
import matplotlib.pyplot as plt #Importa MATPlOT, para poder graficar datos de manera basica
import seaborn as sns #Importa SEABORN, para dibujar graficos graficos estadisticos mas precisos, este esta basado en MATPLOT

# %% [markdown]
# ### Habilitar espacio en Google Drive

# %% [markdown]
# Habilitaremos primero Google Ddrive. Esto Abrira un espacio donde obtendremos un link, el cual al intentar acceder nos redirijira a una sesion que generara un clave maestra. Para obtenerla deberemos logearnos con una cuenta de Gmail y acontinuacion copiar dicha contraseña en el espacio especificado de esta seccion de ejecucion del Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')

#Ejemplo de la contraseña que se puede encontrar: 4/1AX4XfWh4e0myiUeLKljxyXxTARFxEuGKy8b88ExpJHyP7VSAqu2nhnL4Eos
# Out:
# Mounted at /content/drive

# %% [markdown]
# Al habilitar esta opcion, abremos creado un espacio dentro de nuestra zona de trabajo, llamada drive, esta aparece en la seccion de carpetas de Colab. A partir de esta podremos acceder a nuestro espacio de googleDrive de la cuenta con la que nos loguiamos anteriormente.
#
# drive/MyDrive/ -->carpetas de mi espacio en Drive

# %% [markdown]
# Ahora que tenemos acceso a nuestro Google Drive, podemos importar los documentos, mas importante aun, nuestras bases de datos,DATASEETS, alojados ahi.

# %% [markdown]
# ### Importar datos de Google Drive

# %%
import pandas as pd
data_frame = pd.read_csv()

# %% [markdown]
# ### Importar desde Github

# %%
import pandas as pd
data_frame = pd.read_csv("https://raw.githubusercontent.com/OnRuiso/Deep-Learning-/main/Codigos/Deep_Learnig_IA_Data/DataSets_P1T4/prestamos_records.csv")
df = data_frame #esta linea es innecesaria, solo esta aqui para cambiar a la forma de nombrar la variable de mabera simplificada
df.head() #Muestra los valores de cabecera de la base de datos
# Out:
#         RECORD_CREATION_DATE  ...  PRESTAMO_INCUMPLIDO
# 0  01May2014:09:24:27.000000  ...                FALSO
# 1  01May2014:09:48:36.000000  ...                FALSO
# 2  01May2014:10:10:36.000000  ...            VERDADERO
# 3  01May2014:10:31:25.000000  ...                FALSO
# 4  01May2014:10:46:54.000000  ...            VERDADERO
#
# [5 rows x 7 columns]

# %% [markdown]
# ### Mostrar un numero de filas especifico

# %%
print("Ahora mostrara los primeros dies (10) datos")
df.head(10)
# Out:
# Ahora mostrara los primeros dies (10) datos
#         RECORD_CREATION_DATE  ...  PRESTAMO_INCUMPLIDO
# 0  01May2014:09:24:27.000000  ...                FALSO
# 1  01May2014:09:48:36.000000  ...                FALSO
# 2  01May2014:10:10:36.000000  ...            VERDADERO
# 3  01May2014:10:31:25.000000  ...                FALSO
# 4  01May2014:10:46:54.000000  ...            VERDADERO
# 5  01May2014:11:14:12.000000  ...                FALSO
# 6  01May2014:11:23:11.000000  ...            VERDADERO
# 7  01May2014:11:53:24.000000  ...                FALSO
# 8  01May2014:12:18:53.000000  ...                FALSO
# 9  01May2014:12:32:41.000000  ...                FALSO
#
# [10 rows x 7 columns]

# %% [markdown]
# Como podemos observar en la tabla anterior, hay algunos datos que figuran cono "NaN", esto quiere decir que son datos vacios, sin embargo para el trabajo de DeepLearning estos no deben existir pues al igual que la interrupcion de una señal intrusa en una señal de radio, estos datos generan ruido en el sistema que vayamos a implementar.

# %% [markdown]
# ### Mostrar Tamaño de la base de datos

# %%
print("La base de datos actual tiene: \n")
print(df.shape)
print("\n Siendo el primer valor X, numero de filas y el segundo valor Y numero de columnas")
# Out:
# La base de datos actual tiene:
#
# (8000, 7)
#
#  Siendo el primer valor X, numero de filas y el segundo valor Y numero de columnas

# %% [markdown]
# Lo que se debe tener en cuenta, es que la base de datos que en este momento estamos manipulando, es aquella que a sido leida de su sitio de origen y ha sido cargada en nuestra variable local. A todas luces, todo lo que manipules, transformemos o modifiquemos sera esta variable LOCAL, nunca la base de datos del origen.

# %% [markdown]
# ### Insertar nuevas columnas

# %%
print("Tambien se puede insertar nuevas columnas")
df.insert(0,'col_1',df.mean(1))
#df.insertame(con valores de 0,nombre de columna,df.mean(posicion de la columna)
df.head(3)
# Out:
# Tambien se puede insertar nuevas columnas
#     col_1  ... PRESTAMO_INCUMPLIDO
# 0  2500.0  ...               FALSO
# 1  2500.0  ...               FALSO
# 2  6300.0  ...           VERDADERO
#
# [3 rows x 8 columns]

# %%
print("Tambien se puede insertar al final directamente una nueva columna")
df['total']=''
df.head(3)
# Out:
# Tambien se puede insertar al final directamente una nueva columna
#     col_1       RECORD_CREATION_DATE  ...  PRESTAMO_INCUMPLIDO total
# 0  2500.0  01May2014:09:24:27.000000  ...                FALSO
# 1  2500.0  01May2014:09:48:36.000000  ...                FALSO
# 2  6300.0  01May2014:10:10:36.000000  ...            VERDADERO
#
# [3 rows x 9 columns]

# %% [markdown]
# ### Operaciones con valores:

# %%
# Con la siguiente operacion decimos que
#La columna de total es IGUAL ( MONTO_DEL_PRESTAMO * 0.19 )
df['total'] = df['MONTO_DEL_PRESTAMO']*0.19
df.head(5)
# Out:
#      col_1       RECORD_CREATION_DATE  ...  PRESTAMO_INCUMPLIDO   total
# 0   2500.0  01May2014:09:24:27.000000  ...                FALSO   475.0
# 1   2500.0  01May2014:09:48:36.000000  ...                FALSO   475.0
# 2   6300.0  01May2014:10:10:36.000000  ...            VERDADERO  1197.0
# 3   4300.0  01May2014:10:31:25.000000  ...                FALSO   817.0
# 4  20100.0  01May2014:10:46:54.000000  ...            VERDADERO  3819.0
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Filtrado de datos

# %%
df [df['PRESTAMO_INCUMPLIDO']=="VERDADERO"] 
#condition = df['coll']>20
# Out:
#         col_1       RECORD_CREATION_DATE  ...  PRESTAMO_INCUMPLIDO   total
# 2      6300.0  01May2014:10:10:36.000000  ...            VERDADERO  1197.0
# 4     20100.0  01May2014:10:46:54.000000  ...            VERDADERO  3819.0
# 6      2500.0  01May2014:11:23:11.000000  ...            VERDADERO   475.0
# 11     2500.0  01May2014:12:59:04.000000  ...            VERDADERO   475.0
# 18     2900.0  01May2014:15:17:40.000000  ...            VERDADERO   551.0
# ...       ...                        ...  ...                  ...     ...
# 7992   2500.0  07May2015:14:43:58.000000  ...            VERDADERO   475.0
# 7993   4400.0  07May2015:15:10:02.000000  ...            VERDADERO   836.0
# 7996   2500.0  07May2015:16:38:22.000000  ...            VERDADERO   475.0
# 7998   2500.0  07May2015:17:37:18.000000  ...            VERDADERO   475.0
# 7999   2500.0  07May2015:17:52:58.000000  ...            VERDADERO   475.0
#
# [1275 rows x 9 columns]

# %%
df [df['MONTO_DEL_PRESTAMO']>20000]
# Out:
#         col_1       RECORD_CREATION_DATE  ...  PRESTAMO_INCUMPLIDO   total
# 4     20100.0  01May2014:10:46:54.000000  ...            VERDADERO  3819.0
# 13    35000.0  01May2014:13:50:52.000000  ...                FALSO  6650.0
# 36    25000.0  02May2014:11:17:53.000000  ...                FALSO  4750.0
# 68    23800.0  05May2014:12:50:26.000000  ...                FALSO  4522.0
# 146   20700.0  08May2014:09:22:54.000000  ...                FALSO  3933.0
# ...       ...                        ...  ...                  ...     ...
# 7867  30400.0  01May2015:14:30:33.000000  ...                FALSO  5776.0
# 7869  20100.0  01May2015:15:23:07.000000  ...                FALSO  3819.0
# 7918  35000.0  05May2015:12:13:29.000000  ...            VERDADERO  6650.0
# 7962  22400.0  06May2015:15:50:39.000000  ...            VERDADERO  4256.0
# 7978  35000.0  07May2015:10:39:21.000000  ...                FALSO  6650.0
#
# [413 rows x 9 columns]

# %% [markdown]
# # Ejercicio 2
# Ejercicio para trabajar con bases de datos (DATASETS), se trabajaran con dos bases de datos por el momento:
#
# 2. "user_timestamp.csv".

# %% [markdown]
# ## Importar librerias

# %%
import numpy as np #Importa de NUMPY, con el podremos manejar vectores y matrices
import pandas as pd #Importa PANDAS, para trabajar con bases de datos
import matplotlib.pyplot as plt #Importa MATPlOT, para poder graficar datos de manera basica
import seaborn as sns #Importa SEABORN, para dibujar graficos graficos estadisticos mas precisos, este esta basado en MATPLOT

# %% [markdown]
# ## Importar la database

# %%
df_time= pd.read_csv("https://raw.githubusercontent.com/OnRuiso/Deep-Learning-/main/Codigos/Deep_Learnig_IA_Data/DataSets_P1T4/user_timestamp.csv")
#esta linea es innecesaria, solo esta aqui para cambiar a la forma de nombrar la variable de mabera simplificada
df_time.head(10) #Muestra los valores de cabecera de la base de datos
# Out:
#    user_id timestamp
# 0    621.0   0:00:02
# 1    818.0   0:00:10
# 2      4.0   0:00:21
# 3    563.0   0:00:21
# 4    671.0   0:00:26
# 5    780.0   0:00:28
# 6    136.0   0:00:33
# 7    621.0   0:00:58
# 8    136.0   0:01:00
# 9    831.0   0:01:04

# %% [markdown]
# ## Tamaño de la base de datos

# %%
print(df_time.shape) #Tamaño de la base de datos
# Out:
# (71996, 2)

# %% [markdown]
# ## Eliminar datos nulos

# %%
df_time.timestamp.isnull().sum() ##suma por cada dato nulo en "timestamp" de la base de datos"df_time"
# Out:
# 10414

# %% [markdown]
# Como podemos ver hay en la base de datos 10414 datos que son nulos.
# Creare una variable auxiliar que guardara todos aquellos valores de df_time que son nulos, el tamaño de esta nueva base de datos auxiliar debera ser igual al valor de la suma anterior.

# %%
df_aux = df_time[df_time.timestamp.isnull()]
##df_aux sera igual a los valores nulos de timesstamp de df_time, esto en una columna de df_time
df_aux.shape #tamaño de df_aux
# Out:
# (10414, 2)

# %% [markdown]
# Como podemos comprobar, los datos en df_aux son exactamento los datos nulos que habiamos contado anteriormente en def_time.
# La anterior variable df_aux, solo es para comprobar el conteo de datos nulos.

# %%
## Ahora aplicare la funcion drop
df_time.drop(df_time[df_time.timestamp.isnull()].index, inplace=True)
"""
leyendo <---
reemplazar(SI) todos los indices de "df_time" cuyos valores en timestamp son 
nulos, el reemplazo es Quitar (drop) de df_time
"""
# Out:
# '\nleyendo <---\nreemplazar(SI) todos los indices de "df_time" cuyos valores en timestamp son \nnulos, el reemplazo es Quitar (drop) de df_time\n'

# %% [markdown]
# Habiendo hecho lo anterior solo queda comprobar el tamaño de la base de datos a ver si no exiten esos valores.

# %%
df_time.shape
# Out:
# (61582, 2)

# %% [markdown]
# Sabemos que los ha quitado ya que el tamaño original de filas era 71996 al cual le quitamos 10414 datos, por lo que quedamos con 61582. YA ELIMINAMOS LOS DATOS NULOS

# %% [markdown]
# ## Filtrar datos y representarlos

# %%
df_time.head(3)
# Out:
#    user_id timestamp
# 0    621.0   0:00:02
# 1    818.0   0:00:10
# 2      4.0   0:00:21

# %% [markdown]
# Solo quiero ver, por ejemplo, todos los datos del usuario 621.0

# %%
#df [df['PRESTAMO_INCUMPLIDO']=="VERDADERO"] 
user_1 = df_time[df_time['user_id']==621.0]
user_1.shape
# Out:
# (59, 983)

# %% [markdown]
# con el anterior filtro puedo ver que hay 59 filas que corresponden a los datos del usuario 621.0 , sin embargo aparecieron porque AJA en el momento 983 columnas, de las cuales solo me interesan dos, user_id y timestamp.

# %%
print(user_1.keys()) # ver los datos que contiene la base de datos
# Out:
# Index([  'user_id', 'timestamp',       621.0,       818.0,         4.0,
#              563.0,       671.0,       780.0,       136.0,       831.0,
#        ...
#              845.0,       747.0,       558.0,       555.0,       408.0,
#              488.0,       425.0,       804.0,       525.0,       378.0],
#       dtype='object', length=983)

# %%
user_1.head(3)
# Out:
#      user_id timestamp  621.0  818.0    4.0  ...  488.0  425.0  804.0  525.0  378.0
# 0      621.0   0:00:02  621.0  621.0  621.0  ...  621.0  621.0  621.0  621.0  621.0
# 7      621.0   0:00:58  621.0  621.0  621.0  ...  621.0  621.0  621.0  621.0  621.0
# 104    621.0   0:15:13  621.0  621.0  621.0  ...  621.0  621.0  621.0  621.0  621.0
#
# [3 rows x 983 columns]

# %%
#df.insert(0,'col_1',df.mean(1))
user_1.insert(0,'serial',user_1.mean(1))
user_1['serial']=range(1,60)
user_1.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      serial  user_id timestamp  621.0  818.0  ...  488.0  425.0  804.0  525.0  378.0
# 0         1    621.0   0:00:02  621.0  621.0  ...  621.0  621.0  621.0  621.0  621.0
# 7         2    621.0   0:00:58  621.0  621.0  ...  621.0  621.0  621.0  621.0  621.0
# 104       3    621.0   0:15:13  621.0  621.0  ...  621.0  621.0  621.0  621.0  621.0
#
# [3 rows x 984 columns]

# %%
sns.set(rc={"figure.figsize":(5,5)})#tamaño del grafico
sns.distplot(user_1["serial"]) #Se agrega los datos a la grafica
plt.show() #Se muestra el grafico
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt

#x=[datetime.strptime(date, "%I-%M-%S").date() for date in user_1.timestamp]
x=user_1.timestamp
y=user_1.serial
plt.xlabel("Serial")
plt.axis([0,60,0,70])
plt.rcParams["figure.figsize"] = (25,4)
plt.plot(x,y,marker="o")
plt.show()

# %% [markdown]
# # Trabajo aparte con SKLEARN

# %% [markdown]
# ## cargando datos de sklearn

# %%
from sklearn.datasets import load_boston
boston_dataset = load_boston()

# %% [markdown]
# ## Ver los datos del dataset

# %%
print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# ## Ver las caracteristicas de los datos

# %%
boston_dataset.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston_dataset.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
boston_dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston_dataset.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
boston_dataset.filename
# Out:
# '/usr/local/lib/python3.7/dist-packages/sklearn/datasets/data/boston_house_prices.csv'

# %% [markdown]
# ## Crear tabla de datos

# %%
# Se crea una tabla con filas=data   columnas=nombresCaracteristicos
boston = pd.DataFrame(boston_dataset.data,columns=boston_dataset.feature_names)
boston.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6195777331a6> in <module>()
#       1 # Se crea una tabla con filas=data   columnas=nombresCaracteristicos
# ----> 2 boston = pd.DataFrame(boston_dataset.data,columns=boston_dataset.feature_names)
#       3 boston.head(10)
#
# NameError: name 'pd' is not defined

# %%
# agregar en la tabla los datos del target
boston["MEDV"]=boston_dataset.target #agrega una columa al final llamada MEDV con los datos de tarjeta
boston.head(10)

# %% [markdown]
# ## Graficos de datos

# %%
sns.set(rc={"figure.figsize":(11.7,8.27)})#tamaño del grafico
sns.distplot(boston["MEDV"]) #Se agrega los datos a la grafica
plt.show() #Se muestra el grafico

# %% [markdown]
# ## Matrix de Correlacion de caracteristicas

# %%
correlation_matrix = boston.corr().round(2)
##grafico de correlacion de pandas
## mientras el valor cea mas cercano a 1 mejor correlacion tendra
## mientras mas alejado de 1 peor correlacion tendra
sns.heatmap(data=correlation_matrix,annot=True)
#graficara utilizando sns
## annot = True ; imprimira los valores dentro del cuadro

# %% [markdown]
# El coeficiente de correlacion oscila entre -1 y 1.
# Si el valor esta cerca de 1 , significa que hay una fuerte correlacion positiva entre las dos variables-
# Si el valor esta cerca de -1 , las variables tienen una fuerte correlacion negativa.
